# %% [markdown]
# This is a starter notebook for the project, you'll have to import the libraries you'll need, you can find a list of the ones available in this workspace in the requirements.txt file in this workspace.

# %% [markdown]
# # Project: Personalized Real Estate Agent
#
# This project is the final submission for the Udacity Generative AI Course

# %% [markdown]
# ## Step 1: Python Setup

# %%
import os

os.environ["LANGCHAIN_TRACING_V2"] = "false"
os.environ["ANONYMIZED_TELEMETRY"] = "false"

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = ""
if "OPENAI_API_BASE" not in os.environ:
    os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
from typing import List
from pydantic import BaseModel
from langchain.prompts import PromptTemplate
from langchain.output_parsers import PydanticOutputParser
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.schema import Document
from langchain.chains.question_answering import load_qa_chain

# %% [markdown]
# ## Step 2: Generating Real Estate Listings

# %%
class Listing(BaseModel):
    neighborhood: str
    price: str
    bedrooms: int
    bathrooms: int
    house_size: str
    description: str
    neighborhood_description: str

class ListingList(BaseModel):
    listings: List[Listing]

# %%
parser = PydanticOutputParser(pydantic_object=ListingList)

prompt = PromptTemplate(
    template=(
        "You are a helpful assistant that generates realistic real estate listings.\n"
        "Generate {num_listings} real estate listings for {city}. "
        "Use descriptive language. Output must follow this schema:\n"
        "{format_instructions}"
    ),
    input_variables=["num_listings", "city", "format_instructions"],
)

model = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0.7,
)

chain = LLMChain(
    llm=model,
    prompt=prompt,
    output_parser=parser
)

generated_listings = chain.run({
    "num_listings": 20,
    "city": "San Francisco",
    "format_instructions": parser.get_format_instructions()
})

print(generated_listings)
# Out:
# listings=[Listing(neighborhood='Pacific Heights', price='$2,500,000', bedrooms=3, bathrooms=2, house_size='2,000 sqft', description='Beautiful Victorian home with stunning views of the Golden Gate Bridge.', neighborhood_description='Upscale neighborhood known for its historic architecture and panoramic views.'), Listing(neighborhood='Mission District', price='$1,200,000', bedrooms=2, bathrooms=1, house_size='1,100 sqft', description='Modern condo with open floor plan and rooftop deck.', neighborhood_description='Vibrant neighborhood with diverse culture and vibrant nightlife.'), Listing(neighborhood='Noe Valley', price='$3,000,000', bedrooms=4, bathrooms=3, house_size='2,500 sqft', description='Luxury single-family home with gourmet kitchen and backyard oasis.', neighborhood_description='Family-friendly area with trendy shops and cafes.'), Listing(neighborhood='Russian Hill', price='$1,800,000', bedrooms=2, bathrooms=2, house_size='1,600 sqft', description='Charming cottage with bay windows and private garden.', neighborhood_description='Quaint neighborhood with hilly streets and stunning views of the Bay.'), Listing(neighborhood='Marina District', price='$2,700,000', bedrooms=3, bathrooms=2, house_size='2,300 sqft', description='Waterfront condo with panoramic views of the Marina.', neighborhood_description='Sought-after area with upscale dining and outdoor activities.'), Listing(neighborhood='North Beach', price='$1,500,000', bedrooms=2, bathrooms=1, house_size='1,400 sqft', description='Cozy apartment with city views and close to popular cafes.', neighborhood_description='Historic neighborhood known for its Italian heritage and lively atmosphere.'), Listing(neighborhood='Potrero Hill', price='$2,400,000', bedrooms=3, bathrooms=2, house_size='2,100 sqft', description='Modern townhouse with rooftop terrace and city skyline views.', neighborhood_description='Sunny neighborhood with industrial roots and trendy eateries.'), Listing(neighborhood='Sunset District', price='$1,000,000', bedrooms=2, bathrooms=1, house_size='1,000 sqft', description='Remodeled bungalow with backyard garden and ocean views.', neighborhood_description='Residential area with diverse community and access to outdoor recreation.'), Listing(neighborhood='Hayes Valley', price='$1,700,000', bedrooms=3, bathrooms=2, house_size='1,800 sqft', description='Historic Victorian home with modern updates and private patio.', neighborhood_description='Trendy neighborhood with boutique shops and gourmet restaurants.'), Listing(neighborhood='Twin Peaks', price='$2,800,000', bedrooms=4, bathrooms=3, house_size='2,400 sqft', description='Contemporary hillside home with panoramic city views and rooftop deck.', neighborhood_description='Exclusive area with breathtaking views and easy access to hiking trails.'), Listing(neighborhood='Presidio Heights', price='$4,500,000', bedrooms=5, bathrooms=4, house_size='3,500 sqft', description='Elegant mansion with landscaped gardens and bay views.', neighborhood_description='Prestigious neighborhood with grand homes and proximity to Presidio park.'), Listing(neighborhood='Cole Valley', price='$1,600,000', bedrooms=3, bathrooms=2, house_size='1,700 sqft', description='Cozy cottage with sunny backyard and walking distance to Golden Gate Park.', neighborhood_description='Quaint area with tree-lined streets and charming cafes.'), Listing(neighborhood='Haight-Ashbury', price='$1,300,000', bedrooms=2, bathrooms=1, house_size='1,300 sqft', description='Bohemian-style apartment with vintage decor and views of the neighborhood.', neighborhood_description='Historic district known for its hippie culture and eclectic shops.'), Listing(neighborhood='Nob Hill', price='$3,200,000', bedrooms=4, bathrooms=3, house_size='2,800 sqft', description='Luxurious penthouse with private elevator and panoramic city views.', neighborhood_description='Exclusive enclave with upscale hotels and historic landmarks.'), Listing(neighborhood='Castro District', price='$1, ...

# %% [markdown]
# ## Step 3: Storing Listings in a Vector Database

# %%
listings = generated_listings.listings if hasattr(generated_listings, "listings") else generated_listings

docs = [
    Document(
        page_content=(
            f"{l.neighborhood} | {l.price} | {l.bedrooms} BR / {l.bathrooms} BA | {l.house_size}\n"
            f"{l.description}\n"
            f"Neighborhood: {l.neighborhood_description}"
        ),
        metadata={
            "neighborhood": l.neighborhood,
            "price": l.price,
            "bedrooms": l.bedrooms,
            "bathrooms": l.bathrooms,
            "house_size": l.house_size,
        },
    )
    for l in listings
]

# Embeddings & Vectorstore
embeddings = OpenAIEmbeddings()
db = Chroma.from_documents(docs, embeddings, collection_name="real_estate_listings")
# Out:
# Failed to send telemetry event client_start: capture() takes 1 positional argument but 3 were given

# %% [markdown]
# # Step 4: Building the User Preference Interface

# %%
# From the Instruction of the Udemy Course
questions = [   
                "How big do you want your house to be?", 
                "What are 3 most important things for you in choosing this property?", 
                "Which amenities would you like?", 
                "Which transportation options are important to you?",
                "How urban do you want your neighborhood to be?",   
            ]
answers = [
    "A comfortable three-bedroom house with a spacious kitchen and a cozy living room.",
    "A quiet neighborhood, good local schools, and convenient shopping options.",
    "A backyard for gardening, a two-car garage, and a modern, energy-efficient heating system.",
    "Easy access to a reliable bus line, proximity to a major highway, and bike-friendly roads.",
    "A balance between suburban tranquility and access to urban amenities like restaurants and theaters."]

# Build user interaction string (question, answer, question, answer...)
interaction_parts = []
for q, a in zip(questions, answers):
    interaction_parts.append(f"Q: {q}")
    interaction_parts.append(f"A: {a}")

user_interaction = "\n".join(interaction_parts)



pref_prompt = PromptTemplate(
    template=(
        "Summarize the following buyer Q/A into a short buyer profile (3-5 bullet points).\n\n"
        "{user_interaction}"
    ),
    input_variables=["user_interaction"],
)

buyer_profile = LLMChain(llm=model, prompt=pref_prompt).run(
    user_interaction=user_interaction
)
print("Buyer profile:\n", buyer_profile)
# Out:
# Buyer profile:
#  - Looking for a comfortable three-bedroom house with spacious kitchen and cozy living room
# - Prioritizes quiet neighborhood, good local schools, and convenient shopping options
# - Desires amenities such as backyard for gardening, two-car garage, and modern heating system
# - Values easy access to reliable bus line, proximity to major highway, and bike-friendly roads
# - Seeks a neighborhood that balances suburban tranquility with access to urban amenities like restaurants and theaters

# %% [markdown]
# ## Step 5: Searching Based on Preferences

# %%
# Similarity Search mit der User-Interaktion als Query
suitable_listings = db.similarity_search(buyer_profile, k=3)

print(f"\n{'='*80}")
print(f"Found {len(suitable_listings)} suitable listings:")
print('='*80)

for i, doc in enumerate(suitable_listings, start=1):
    print(f"\n[Listing {i}]")
    print(f"Neighborhood: {doc.metadata.get('neighborhood', 'N/A')}")
    print(f"Price: {doc.metadata.get('price', 'N/A')}")
    print(f"Bedrooms: {doc.metadata.get('bedrooms', 'N/A')} | Bathrooms: {doc.metadata.get('bathrooms', 'N/A')}")
    print(f"Size: {doc.metadata.get('house_size', 'N/A')}")
    print(f"\nDescription:\n{doc.page_content[:200]}...")
    print('-'*80)
# Out:
# ================================================================================
# Found 3 suitable listings:
# ================================================================================
#
# [Listing 1]
# Neighborhood: Noe Valley
# Price: $3,000,000
# Bedrooms: 4 | Bathrooms: 3
# Size: 2,500 sqft
#
# Description:
# Noe Valley | $3,000,000 | 4 BR / 3 BA | 2,500 sqft
# Luxury single-family home with gourmet kitchen and backyard oasis.
# Neighborhood: Family-friendly area with trendy shops and cafes....
# --------------------------------------------------------------------------------
#
# [Listing 2]
# Neighborhood: Noe Valley
# Price: $1,800,000
# Bedrooms: 3 | Bathrooms: 2
# Size: 1,800 sqft
#
# Description:
# Noe Valley | $1,800,000 | 3 BR / 2 BA | 1,800 sqft
# Contemporary remodeled home with an open floor plan, high ceilings, and modern finishes. Private backyard with a deck perfect for entertaining.
# Neigh...
# --------------------------------------------------------------------------------
#
# [Listing 3]
# Neighborhood: Bernal Heights
# Price: $2,100,000
# Bedrooms: 3 | Bathrooms: 2
# Size: 1,900 sqft
#
# Description:
# Bernal Heights | $2,100,000 | 3 BR / 2 BA | 1,900 sqft
# Contemporary home with hillside garden and city skyline views.
# Neighborhood: Quirky neighborhood with local art scene and trendy eateries....
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Step 6: Personalizing Listing Descriptions

# %%
augment_prompt = PromptTemplate(
    template=(
        "You are a professional home seller and expert copywriter. Your goal is to make every listing sound as appealing as possible, while staying fully factual.\n"
        "RULES:\n"
        "- Do NOT give out the facts such as price, sqft, number of rooms.\n"
        "- Do NOT invent anything that is not already in the listing.\n"
        "- You MAY rephrase, reorder, and emphasize parts that match the buyer.\n"
        "- Use vivid, positive language and highlight unique features.\n"
        "- Make the description emotionally engaging and persuasive, as if you were selling the home to a friend.\n"
        "BUYER PROFILE:\n{buyer_profile}\n"
        "ORIGINAL LISTING:\n{listing}\n"
        "Rewritten listing:"
    ),
    input_variables=["buyer_profile", "listing"],
)

augment_chain = LLMChain(llm=model, prompt=augment_prompt)

for i, doc in enumerate(suitable_listings, start=1):
    augmented = augment_chain.run(
        buyer_profile=buyer_profile,
        listing=doc.page_content,
    )
    print(f"\n[Listing {i}]")
    print(f"Neighborhood: {doc.metadata.get('neighborhood', 'N/A')}")
    print(f"Price: {doc.metadata.get('price', 'N/A')}")
    print(f"Bedrooms: {doc.metadata.get('bedrooms', 'N/A')} | Bathrooms: {doc.metadata.get('bathrooms', 'N/A')}")
    print(f"Size: {doc.metadata.get('house_size', 'N/A')}")
    print(f"\nDescription:\n{augmented.strip()}") # Here the augmented description is used
    print('-'*80)
# Out:
# [Listing 1]
# Neighborhood: Noe Valley
# Price: $3,000,000
# Bedrooms: 4 | Bathrooms: 3
# Size: 2,500 sqft
#
# Description:
# Welcome to the charming neighborhood of Noe Valley, where this luxurious single-family home awaits you. Step inside to find a spacious gourmet kitchen, perfect for preparing delicious meals and hosting gatherings with loved ones. The cozy living room is ideal for relaxing after a long day, while the backyard oasis provides a peaceful retreat for gardening or enjoying the fresh air.
#
# Located in a family-friendly area, this home is surrounded by trendy shops and cafes, offering the perfect blend of suburban tranquility and urban convenience. With easy access to a reliable bus line and proximity to major highways, commuting is a breeze. Plus, the neighborhood boasts bike-friendly roads for those who prefer to cycle.
#
# Don't miss the two-car garage for convenient parking and the modern heating system for ultimate comfort. This home is perfect for those seeking a comfortable three-bedroom house with all the amenities you desire. Come and see for yourself - your dream home awaits!
# --------------------------------------------------------------------------------
#
# [Listing 2]
# Neighborhood: Noe Valley
# Price: $1,800,000
# Bedrooms: 3 | Bathrooms: 2
# Size: 1,800 sqft
#
# Description:
# Step into this modern oasis in the heart of Noe Valley, where contemporary design meets cozy comfort. With an inviting open floor plan, high ceilings, and sleek finishes, this remodeled home is the perfect blend of style and functionality.
#
# Escape to your own private backyard sanctuary, complete with a charming deck that's ideal for hosting family gatherings or simply relaxing in the sunshine. Imagine sipping your morning coffee surrounded by lush greenery and the peaceful sounds of nature.
#
# Nestled in the family-friendly neighborhood of Noe Valley, you'll enjoy easy access to trendy boutiques, cafes, and convenient public transportation options. Whether you're exploring the local shops or hopping on the nearby bus line for a quick commute, this location offers the perfect balance of suburban tranquility and urban convenience.
#
# Don't miss the opportunity to make this your dream home, where every detail has been thoughtfully designed for modern living. Welcome to your own slice of paradise in Noe Valley.
# --------------------------------------------------------------------------------
#
# [Listing 3]
# Neighborhood: Bernal Heights
# Price: $2,100,000
# Bedrooms: 3 | Bathrooms: 2
# Size: 1,900 sqft
#
# Description:
# Welcome to your new sanctuary in the vibrant Bernal Heights neighborhood! This contemporary home offers stunning city skyline views from the hillside garden, providing the perfect backdrop for your morning coffee or evening relaxation.
#
# Immerse yourself in the quirky local art scene and trendy eateries that make this neighborhood so unique. With three cozy bedrooms and two bathrooms, this home is the perfect blend of comfort and style.
#
# Enjoy the spacious kitchen, perfect for whipping up delicious meals and hosting gatherings with friends and family. The cozy living room is ideal for relaxing after a long day, with plenty of natural light streaming in through the windows.
#
# Step outside to the backyard, where you can indulge your green thumb with gardening or simply unwind in the fresh air. The two-car garage provides ample storage space for all your outdoor gear, and the modern heating system ensures your comfort year-round.
#
# With easy access to a reliable bus line, major highways, and bike-friendly roads, getting around town is a breeze. This neighborhood offers the perfect balance of suburban tranquility and urban amenities, with a variety of restaurants and theaters just a short distance away.
#
# Don't miss out on this incredible opportunity to make this house your home!
# --------------------------------------------------------------------------------
